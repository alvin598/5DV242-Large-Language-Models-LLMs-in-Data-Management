# %% [markdown]
# # Question 1

# %%
import torch
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/__init__.py:2821
#    2817     torch_module_name = ".".join([__name__, device_type])
#    2818     sys.modules[torch_module_name] = module
# -> 2821 from torch import (
#    2822     export as export,
#    2823     func as func,
#    2824     library as library,
#    2825     return_types as return_types,
#    2826 )
#    2827 from torch._higher_order_ops import cond as cond, while_loop as while_loop
#    2828 from torch.func import vmap as vmap
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/export/__init__.py:42
#      39 import torch.export.custom_ops
#      41 from ._state_dict_utils import _restore_state_dict
# ...
