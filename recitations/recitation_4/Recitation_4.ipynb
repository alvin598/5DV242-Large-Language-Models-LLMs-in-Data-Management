# %%
from TurtleAGI import turtleAGI

turtleAGI("Build a website")
# Out:
# NEXT TASK: Develop a task list, DEPTH: 0
#
# NEXT TASK: Define Website Goals  Objectives, DEPTH: 1
#
# User injection: Importnat to add task to reaserch if to use .com or .net domain
#
# NEXT TASK: Choose a Development Method, DEPTH: 1
#
# NEXT TASK: Choose a Domain Name, DEPTH: 2
#
# NEXT TASK: Select a Website Development Method CodeFirst or LowCodeNoCode, DEPTH: 2
#
# NEXT TASK: Select a Website Development Method CodeFirst or LowCodeNoCode, DEPTH: 2
#
# NEXT TASK: Hosting Provider Selection, DEPTH: 1
#
# User injection: Important to return the task in capital letters
#
# NEXT TASK: REGISTER THE CHOSEN DOMAIN NAME, DEPTH: 2
#
# NEXT TASK: SET UP A DEVELOPMENT ENVIRONMENT BASED ON CHOSEN METHOD, DEPTH: 2
#
# NEXT TASK: DESIGN THE WEBSITE LAYOUT AND USER INTERFACE, DEPTH: 2
#
# User injection: Make this the last task
#
# NEXT TASK: DEVELOP THE WEBSITE CONTENT, DEPTH: 2
#
# NEXT TASK: IMPLEMENT WEBSITE FUNCTIONALITY, DEPTH: 2
#
# NEXT TASK: TEST THE WEBSITE THOROUGHLY, DEPTH: 2
#
# ...
