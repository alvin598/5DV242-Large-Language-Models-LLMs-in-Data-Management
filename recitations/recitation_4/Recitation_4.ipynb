# %%
from TurtleAGI import turtleAGI

turtleAGI("Solve world hunger")
# Out:
# NEXT TASK: Develop a task list, DEPTH: 0
#
# NEXT TASK: Establish and manage efficient logistics for delivering emergency food rations trucks ships air transport, DEPTH: 1
#
# NEXT TASK: Develop a comprehensive database of local food producers and their current production levels considering potential for scaling up to meet increased demand, DEPTH: 2
#
# NEXT TASK: Rapid assessment of acutely food insecure regions using satellite imagery local reports and NGOs, DEPTH: 1
#
# NEXT TASK: Develop a system for predicting and mitigating potential disruptions to food supply chains including climaterelated events and political instability, DEPTH: 2
#
# NEXT TASK: Develop a predictive model incorporating climate data agricultural yields and market prices to forecast potential food shortages, DEPTH: 2
#
# NEXT TASK: Establish a centralized data platform integrating satellite imagery local reports and NGO data for realtime monitoring and analysis, DEPTH: 2
#
# ...
